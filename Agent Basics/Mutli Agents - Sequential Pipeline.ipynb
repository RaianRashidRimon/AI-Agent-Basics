# %% [markdown]
# <img width="1000" src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day1/sequential-agent.png" alt="Sequential Agent" />

# %%
# creating a sequential pipeline

# first an outline agent, which creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline", # result from the agent is stored with this key
)
print("outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# the second agent
# a writer agent, which writes the full blog post based on the result from the first agent.
writer_agent = Agent(
    name="WriterAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft", # result of this agent will be stored with this key.
)
print("writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# the third agent
# an editor agent, which edits and polishes the draft from the previous agent (writer agent)
editor_agent = Agent(
    name="EditorAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog", # this key stores the final output of the whole pipeline.
)
print("editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
# creating a root agent to run it all in a sequential pipeline
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)
print(" Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a blog post about the benefits of multi-agent systems for software developers")
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > ## OutlineAgent: Blog Post Outline Generation
#
# **Topic:** Benefits of Multi-Agent Systems for Software Developers
#
# ---
#
# ### **1. Catchy Headline:**
#
# **Unleash Your Development Superpowers: How Multi-Agent Systems Are Revolutionizing Software**
#
# ### **2. Introduction Hook:**
#
# Are you tired of monolithic codebases that feel like trying to navigate a labyrinth? Do you dream of building more robust, adaptable, and intelligent software? Get ready to discover a paradigm shift that's empowering developers like never before: **Multi-Agent Systems (MAS)**. Forget rigid, one-size-fits-all solutions; MAS offers a flexible and powerful approach to tackling complex software challenges.
#
# ### **3. Main Sections:**
#
# **Section 1: Breaking Down Complexity with Modular Brilliance**
#
# *   **Decomposition Done Right:** Learn how MAS allows you to break down large, intricate problems into smaller, manageable, and independent "agents." This makes development, debugging, and maintenance significantly less daunting.
# *   **Specialization and Reusability:** Each agent can be designed with a specific purpose and skill set. This specialization leads to cleaner, more focused code and opens doors for reusing agents across different projects.
# *   **Parallel Development & Faster Iteration:** With independent agents, multiple developers or teams can work on different parts of the system simultaneously, dramatically accelerating the development lifecycle.
#
# **Section 2: Building Smarter, More Resilient Software**
#
# *   **Enhanced Adaptability and Flexibility:** MAS excels in dynamic environments. If one agent fails or circumstances change, other agents can adapt, take over, or learn to compensate, leading to more resilient and fault-tolerant systems.
# *   **Intelligent Decision-Making and Problem Solving:** Agents can be programmed with sophisticated reasoning capabilities, enabling them to make autonomous decisions, collaborate to solve complex problems, and even learn from their interactions.
# *   **Emergent Behavior for Innovation:** When agents interact, unexpected and beneficial behaviors can emerge. This can lead to novel solutions and optimizations that might not have been explicitly programmed, fostering a more innovative development process.
#
# **Section 3: Unlocking New Possibilities and Enhanced Efficiency**
#
# *   **Simulating Complex Real-World Scenarios:** MAS is ideal for creating realistic simulations in fields like logistics, gaming, scientific research, and more, allowing developers to test and refine complex systems before deployment.
# *   **Streamlining Automation and Optimization:** Imagine automating intricate workflows, optimizing resource allocation, or creating intelligent assistants. MAS provides the framework to build these advanced automation solutions.
# *   **Improving User Experience through Personalization:** Agents can be designed to understand individual user needs and preferences, delivering highly personalized and dynamic experiences that static software struggles to achieve.
#
# ### **4. Concluding Thought:**
#
# Multi-Agent Systems are no longer a niche concept for the academic elite. For the forward-thinking software developer, embracing MAS is about unlocking a new level of creative potential and building software that is not just functional, but truly intelligent, adaptable, and robust. So, are you ready to start building your own team of digital super-agents?
# WriterAgent > ## Unleash Your Development Superpowers: How Multi-Agent Systems Are Revolutionizing Software
#
# Are you tired of monolithic codebases that feel like trying to navigate a labyrinth? Do you dream of building more robust, adaptable, and intelligent software? Get ready to discover a paradigm shift that's empowering developers like never before: **Multi-Agent Systems (MAS)**. Forget rigid, one-size-fits-all solutions; MAS offers a flexible and powerful approach to tackling complex software challenges.
#
# One of the most significant advantages of MAS is its **modular brilliance**. Large, intricate problems can be broken down into smaller, manageable, and independent "agents." This decomposition makes development, debugging, and maintenance significantly less daunting. Each agent can be designed with a specific purpose and skill set, leading to cleaner, more focused code and opening doors for reusability across projects. This modularity also facilitates **parallel development**, allowing multiple developers or teams to work on different parts of the system simultaneously, dramatically accelerating the development lifecycle.
#
# Beyond breaking down complexity, MAS enables the creation of **smarter, more resilient software**. These systems excel in dynamic environments. If one agent fails or circumstances change, others can adapt, take over, or learn to compensate, leading to more fault-tolerant systems. Agents can be programmed with sophisticated reasoning capabilities, enabling autonomous decision-making and collaborative problem-solving. This intelligent interaction can even lead to **emergent behavior**, unlocking novel solutions and optimizations that weren't explicitly programmed, fostering innovation.
#
# Ultimately, embracing MAS unlocks new possibilities and enhances efficiency. It's ideal for creating realistic simulations, streamlining complex automation, and even improving user experience through deep personalization. Multi-Agent Systems are no longer a niche concept; for the forward-thinking developer, they represent a powerful pathway to building software that is truly intelligent, adaptable, and robust. Are you ready to build your team of digital super-agents?
# EditorAgent > ## Unleash Your Development Superpowers: How Multi-Agent Systems Are Revolutionizing Software
#
# Are you tired of wrestling with monolithic codebases that feel more like a labyrinth than a development environment? Do you aspire to build software that's not just functional, but truly robust, adaptable, and intelligent? If so, prepare to discover a paradigm shift that's empowering developers like never before: **Multi-Agent Systems (MAS)**. Moving beyond rigid, one-size-fits-all solutions, MAS offers a flexible and powerful approach to tackling even the most complex software challenges.
#
# One of the most significant advantages of MAS lies in its **modular brilliance**. Imagine breaking down large, intricate problems into a collection of smaller, manageable, and independent "agents." This decomposition transforms daunting development, debugging, and maintenance tasks into significantly less intimidating processes. Each agent can be meticulously designed with a specific purpose and skill set. This specialization not only leads to cleaner, more focused code but also opens exciting doors for reusability across diverse projects. Furthermore, this inherent modularity facilitates **parallel development**, allowing multiple developers or even entire teams to work concurrently on different system components, thereby dramatically accelerating the entire development lifecycle.
#
# Beyond its prowess in dissecting complexity, MAS empowers the creation of **smarter, more resilient software**. These systems truly shine in dynamic environments. Should one agent encounter a failure or should external circumstances shift, other agents can adapt, seamlessly take over responsibilities, or learn to compensate for the disruption. This inherent adaptability results in systems that are significantly more fault-tolerant. Moreover, agents can be imbued with sophisticated reasoning capabilities, enabling them to make autonomous decisions and engage in collaborative problem-solving. This intelligent interaction can even lead to **emergent behavior**, where novel solutions and optimizations arise organically, rather than being explicitly programmed, thus fostering a truly innovative development process.
#
# Ultimately, embracing MAS unlocks a wealth of new possibilities and significantly enhances efficiency. It proves invaluable for creating realistic simulations, streamlining intricate automation processes, and even elevating user experiences through profound personalization. Multi-Agent Systems are no longer a fringe concept confined to academia; for the forward-thinking developer, they represent a potent pathway to building software that is genuinely intelligent, remarkably adaptable, and exceptionally robust. Are you ready to start assembling your own team of digital super-agents?
